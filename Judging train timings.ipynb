# %%
import os
import librosa
import numpy as np 
import pandas as pd 
from octave_band import plot_custom_bands
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from scipy.signal import spectrogram
from train_period_checker import train_windows
# %matplotlib qt

# %% [markdown]
# # cen_eas

# %% [markdown]
# # hour 00

# %%
wavfile = 'train_recordings/hour0001.wav'
a = [[50,75],[110,140]]
plot_custom_bands(wavfile, bands=a, samplerate=1000,  judged_lines=['cen_eas','cen_wes','bak_sou','bak_nor','vic_sou'],lines=['vic_nor'], ma=1000)

# %% [markdown]
# ### hour 01

# %%
wavfile = 'train_recordings/hour0101.wav'
a = [[50,75],[110,140]]
plot_custom_bands(wavfile, bands=a, samplerate=1000,  judged_lines=['cen_eas','cen_wes','bak_sou','bak_nor','vic_sou'],lines=['vic_nor'], ma=1000)

# %% [markdown]
# ### hour 02

# %%
wavfile = 'train_recordings/hour0201.wav'
a = [[50,75],[110,140]]
plot_custom_bands(wavfile, bands=a, samplerate=1000,  judged_lines=['cen_eas','cen_wes','bak_sou','bak_nor'],lines=['vic_sou'], ma=1000)

# %% [markdown]
# ### hour 03

# %%
wavfile = 'train_recordings/hour0301.wav'
a = [[60,80],[95,120]]
plot_custom_bands(wavfile, array=a, samplerate=1000,  lines=['cen_eas'], ma=1000, vmin=[0.0008,0.001])

# %% [markdown]
# ### hour 04

# %%
wavfile = 'train_recordings/hour0401.wav'
a = [[60,80],[95,120]]
plot_custom_bands(wavfile, array=a, samplerate=1000,  lines=['cen_eas'], ma=1000, vmin=[0.0008,0.001])

# %% [markdown]
# ### hour 05

# %%
wavfile = 'train_recordings/hour0501.wav'
a = [[95,120],[150,170]]
plot_custom_bands(wavfile, bands=a, samplerate=1000,  judged_lines=['cen_eas','cen_wes'],lines=['bak_sou'], ma=1000)

# %% [markdown]
# ### hour 06

# %%
wavfile = 'train_recordings/hour0601.wav'
a = [[50,75],[110,140]]
plot_custom_bands(wavfile, bands=a, samplerate=1000,  judged_lines=['cen_eas','cen_wes','bak_sou','bak_nor','vic_sou'],lines=['vic_nor'], ma=1000)

# %% [markdown]
# ### hour 07

# %%
wavfile = 'train_recordings/hour0701.wav'
a = [[50,75],[110,140]]
plot_custom_bands(wavfile, bands=a, samplerate=1000,  judged_lines=['cen_eas','cen_wes','bak_sou','bak_nor','vic_sou'],lines=['vic_nor'], ma=1000)

# %% [markdown]
# ### hour 08

# %%
wavfile = 'train_recordings/hour0801.wav'
a = [[50,75],[110,140]]
plot_custom_bands(wavfile, bands=a, samplerate=1000,  judged_lines=['cen_eas','cen_wes','bak_sou','bak_nor','vic_sou'],lines=['vic_nor'], ma=1000)

# %% [markdown]
# ### hour 09

# %%
wavfile = 'train_recordings/hour0901.wav'
a = [[50,75],[110,140]]
plot_custom_bands(wavfile, bands=a, samplerate=1000,  judged_lines=['cen_eas','cen_wes','bak_sou','bak_nor','vic_sou'],lines=['vic_nor'], ma=1000)

# %% [markdown]
# ### hour 10

# %%
wavfile = 'train_recordings/hour1001.wav'
a = [[50,75],[110,140]]
plot_custom_bands(wavfile, bands=a, samplerate=1000,  judged_lines=['cen_eas','cen_wes','bak_sou','bak_nor','vic_sou'],lines=['vic_nor'], ma=1000)

# %% [markdown]
# ### hour 11

# %%
wavfile = 'train_recordings/hour1101.wav'
a = [[50,75],[110,140]]
plot_custom_bands(wavfile, bands=a, samplerate=1000,  judged_lines=['cen_eas','cen_wes','bak_sou','bak_nor','vic_sou'],lines=['vic_nor'], ma=1000)

# %% [markdown]
# ### hour 12

# %%
wavfile = 'train_recordings/hour1201.wav'
a = [[50,75],[110,140]]
plot_custom_bands(wavfile, bands=a, samplerate=1000,  judged_lines=['cen_eas','cen_wes','bak_sou','bak_nor','vic_sou'],lines=['vic_nor'], ma=1000)

# %% [markdown]
# ### hour 13

# %%
wavfile = 'train_recordings/hour1301.wav'
a = [[50,75],[110,140]]
plot_custom_bands(wavfile, bands=a, samplerate=1000,  judged_lines=['cen_eas','cen_wes','bak_sou','bak_nor','vic_sou'],lines=['vic_nor'], ma=1000)

# %% [markdown]
# # windows

# %%
import os
import librosa
import numpy as np 
import pandas as pd 
from octave_band import plot_custom_bands
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from scipy.signal import spectrogram
from train_period_checker import train_windows
import datetime
plt.rcParams.update({'font.size': 11})

# %%
# %matplotlib inline

# %%
train_windows(vmin=1e-9, ylim=(50,300), train_line='vic_nor')
# Out:
# Train time: 1669
# Train line: vic_nor
# When does the train start?
# Enter start: exit
# When does the train end?
# Enter end: exit
# published to: judged_timetables/judged_windows_vic_nor1.csv

# %% [markdown]
# ### this below was just to remove index

# %%
print(windows)

# %%
from model_02_functions import input_train_times

# %%
times = ['00','01','02','03','04','05','06','07','08','09','10','11','12','13']
input_train_times(times)

# %%
from model_02_functions import threshold_extract
threshold_extract(0.000175)

# %%
from model_02_functions import find_train_trainbar_array_datetime
import pandas as pd
import datetime

# %%
ar = find_train_trainbar_array_datetime('judged_timetables/judged_timetable_all_rough.csv')

# %%
import scipy
from octave_band import find_octave_band, moving_average

data, samplerate = librosa.load('train_recordings/hour0001.wav', sr=1000)

flower, fupper = find_octave_band(125)
b, a = scipy.signal.butter( N=4, Wn=np.array([flower, fupper])/(samplerate/2), btype='bandpass', analog=False, output='ba')
filtered = abs(scipy.signal.filtfilt(b, a, data))
time = np.linspace(0,len(filtered)/samplerate, len(filtered))
fig = plt.figure(figsize=(16,9), dpi=200)
plt.plot(time, moving_average(filtered, 2000))
plt.plot(range(3600), [0.001*i for i in ar[0]], color='red')
plt.show()

# %%
csv = pd.read_csv('judged_timetables/judged_windows_cen_wes.csv')

# %%
csv

# %%
csv.start = pd.to_datetime(csv.start, format='%Y-%m-%d%H:%M:%S')

# %%
csv.end = pd.to_datetime(csv.end, format='%Y-%m-%d%H:%M:%S')

# %%
csv.to_csv('judged_timetables/judged_windows_cen_wes.csv', index=False)
